# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv ('IceCreamData.csv')
data
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
x_data = data['Temperature'].values.reshape (-1 , 1)
y_data = data['Revenue'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test  = train_test_split (x_data , y_data , test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit (x_train , y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict (x_test)
y_predict
# Out:
# array([511.5709218 , 741.6942032 , 653.38295427, 523.22111724,
#        551.92583443, 474.65020181, 204.3018284 , 623.9008111 ,
#        316.63054415, 705.29217052, 453.2765046 , 697.69786095,
#        597.41011466, 455.17120646, 352.96432179, 240.30149349,
#        469.17276311, 576.96430887, 354.36113936, 663.17287176,
#        611.34845583, 572.79442438, 764.9277853 , 652.02291595,
#        269.91022166, 521.03083523, 603.35577702, 608.80363207,
#        532.41279902, 463.01254648, 308.53693054, 480.79931882,
#        724.6823856 , 562.84470887, 549.92643253, 605.118141  ,
#        177.75145372, 333.22856673, 499.59738947, 365.344201  ,
#        487.86324119, 331.89165083, 668.36042447, 340.57356772,
#        841.39273499, 819.7831046 , 665.46176446, 389.42880886,
#        627.59381554, 623.62105962, 832.31488332, 542.55868805,
#        531.14586435, 397.70959957, 509.38835375, 332.50773716,
#        540.48888044, 401.52412499, 698.74838257, 459.12875109,
#        656.15379973, 476.20528175, 956.61906454, 512.60037589,
#        284.33263504, 572.40248494, 541.16143979, 445.91842525,
#        318.77486574, 792.92664448, 496.66761956, 724.66143631,
#        531.43801052, 559.89922491, 567.2645313 , 319.1231849 ,
#        259.15085   , 571.22461495, 678.46384416, 560.15695615,
#        442.26147745, 471.90809017, 286.4563418 , 456.17761575,
#        524.55424609, 637.07905831, 487.03658781, 647.2036097 ,
#        722.76895998, 266.52360166, 548.10905205, 439.77895967,
#        495.40309518, 720.44303761, 511.41758823, 536.51874053,
#        384.33072501, 607.46117385, 521.95463786, 477.9024853 ])

# %%
plt.scatter (x_test , y_test , color ='green' , label  = 'test data')
plt.plot (x_test , y_predict , color = 'red')
plt.show ()
